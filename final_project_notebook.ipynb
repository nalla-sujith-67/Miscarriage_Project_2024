# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("miscarriageExtended.csv",delimiter = ";")

# %%
df
# Out:
#         Age          BMI  Nmisc  Activity  Binking  Walking  Drinving  \
# 0        22  16,68823896      0         1        0        0         1
# 1        22  16,68823896      0         1        0        0         1
# 2        22  16,68823896      2         1        0        0         1
# 3        22  16,68823896      0         1        0        1         0
# 4        22  16,68823896      1         1        0        1         0
# ...     ...          ...    ...       ...      ...      ...       ...
# 999995   34   26,5300209      1         1        1        0         0
# 999996   34   26,5300209      0         1        1        0         0
# 999997   34   26,5300209      1         1        1        0         0
# 999998   34   26,5300209      2         1        0        1         0
# 999999   34   26,5300209      2         1        1        0         0
#
#         Sitting  Location  temp  bpm  stress  bp  Alcohol Comsumption  Drunk  \
# ...

# %%
df["BMI"] = df["BMI"].str.replace(",",".")
df["BMI"] = df["BMI"].astype("float64")

# %%
df
# Out:
#         Age        BMI  Nmisc  Activity  Binking  Walking  Drinving  Sitting  \
# 0        22  16.688239      0         1        0        0         1        1
# 1        22  16.688239      0         1        0        0         1        1
# 2        22  16.688239      2         1        0        0         1        1
# 3        22  16.688239      0         1        0        1         0        1
# 4        22  16.688239      1         1        0        1         0        1
# ...     ...        ...    ...       ...      ...      ...       ...      ...
# 999995   34  26.530021      1         1        1        0         0        0
# 999996   34  26.530021      0         1        1        0         0        0
# 999997   34  26.530021      1         1        1        0         0        1
# 999998   34  26.530021      2         1        0        1         0        0
# 999999   34  26.530021      2         1        1        0         0        0
#
# ...

# %%
df.describe()
# Out:
#                   Age             BMI           Nmisc   Activity  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.0
# mean        28.002910       21.606415        1.500901        1.0
# std          3.742043        2.961841        1.117784        0.0
# min         22.000000       16.688239        0.000000        1.0
# 25%         25.000000       18.827757        1.000000        1.0
# 50%         28.000000       21.395178        2.000000        1.0
# 75%         31.000000       24.390503        3.000000        1.0
# max         34.000000       26.530021        3.000000        1.0
#
#               Binking         Walking        Drinving         Sitting  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.499314        0.498280        0.002406        0.500419
# std          0.500000        0.499997        0.048992        0.500000
# min          0.000000        0.000000        0.000000        0.000000
# ...

# %%
df.describe().T
# Out:
#                                  count        mean         std         min  \
# Age                          1000000.0   28.002910    3.742043   22.000000
# BMI                          1000000.0   21.606415    2.961841   16.688239
# Nmisc                        1000000.0    1.500901    1.117784    0.000000
# Activity                     1000000.0    1.000000    0.000000    1.000000
# Binking                      1000000.0    0.499314    0.500000    0.000000
# Walking                      1000000.0    0.498280    0.499997    0.000000
# Drinving                     1000000.0    0.002406    0.048992    0.000000
# Sitting                      1000000.0    0.500419    0.500000    0.000000
# Location                     1000000.0    2.001708    1.413462    0.000000
# temp                         1000000.0   37.783945    1.819482   35.000000
# bpm                          1000000.0  128.908990   57.715193   43.000000
# ...

# %%
medians = df.median()

# %%
print(medians)
# Out:
# Age                             28.000000
# BMI                             21.395178
# Nmisc                            2.000000
# Activity                         1.000000
# Binking                          0.000000
# Walking                          0.000000
# Drinving                         0.000000
# Sitting                          1.000000
# Location                         2.000000
# temp                            38.000000
# bpm                            119.000000
# stress                           1.000000
# bp                               2.000000
# Alcohol Comsumption            478.000000
# Drunk                            2.000000
# Miscarriage/ No Miscarriage      0.000000
# dtype: float64

# %%
# from this there is no much difference between the mean and the median so there will not be much skewness in the data

# %%
variances = df.var()

# %%
print(variances)
# Out:
# Age                               14.002890
# BMI                                8.772505
# Nmisc                              1.249440
# Activity                           0.000000
# Binking                            0.250000
# Walking                            0.249997
# Drinving                           0.002400
# Sitting                            0.250000
# Location                           1.997875
# temp                               3.310515
# bpm                             3331.043498
# stress                             1.303348
# bp                                 1.242541
# Alcohol Comsumption            47689.207240
# Drunk                              0.177677
# Miscarriage/ No Miscarriage        0.250000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Age                          1000000 non-null  int64
#  1   BMI                          1000000 non-null  float64
#  2   Nmisc                        1000000 non-null  int64
#  3   Activity                     1000000 non-null  int64
#  4   Binking                      1000000 non-null  int64
#  5   Walking                      1000000 non-null  int64
#  6   Drinving                     1000000 non-null  int64
#  7   Sitting                      1000000 non-null  int64
#  8   Location                     1000000 non-null  int64
#  9   temp                         1000000 non-null  int64
#  10  bpm                          1000000 non-null  int64
#  11  stress                       1000000 non-null  int64
# ...

# %%
df["Miscarriage/ No Miscarriage"].value_counts(normalize = True) #gives the percentage of classes distributed
# Out:
# Miscarriage/ No Miscarriage
# 0    0.500571
# 1    0.499429
# Name: proportion, dtype: float64

# %%
# the dataset is almost perfectly balanced

# %%
classes = df["Miscarriage/ No Miscarriage"].unique()
class_counts = df["Miscarriage/ No Miscarriage"].value_counts()

plt.bar(classes,class_counts,color = ["red","blue"])
plt.ylabel("value counts")
plt.xlabel("target classes")
plt.show()

# %%
df.rename(columns = {"Binking":"Biking","Drinving":"Driving","Alcohol Comsumption":"Alcohol Consumption"},inplace = True)

# %%
df.columns
# Out:
# Index(['Age', 'BMI', 'Nmisc', 'Activity', 'Biking', 'Walking', 'Driving',
#        'Sitting', 'Location', 'temp', 'bpm', 'stress', 'bp',
#        'Alcohol Consumption', 'Drunk', 'Miscarriage/ No Miscarriage'],
#       dtype='object')

# %%
df.drop("Activity",axis = 1,inplace = True)

# %%
target_column = 'Miscarriage/ No Miscarriage'

categorical_columns = ["Location", "Biking", "Walking", "Driving", "Sitting", "stress", "bp", "Drunk"]

features = np.array(df.columns.difference([target_column]))


non_categorical_features = []
for col in features:
    if col not in categorical_columns:
        non_categorical_features.append(col)

# %%
len(non_categorical_features)
# Out:
# 6

# %%
# target = df["Miscarriage/ No Miscarriage"]
# df_plot = pd.concat([df[non_categorical_features],target],axis = 1)

# sns.pairplot(df_plot,hue = "Miscarriage/ No Miscarriage",diag_kind = "kde")
# plt.show()

# %%
plt.figure(figsize = (10,8))

for i,col in enumerate(non_categorical_features):
    plt.subplot(2,3,i+1)
    sns.boxplot(x = df[col])
    plt.title(col)
    plt.xlabel("Values")

plt.tight_layout()
plt.show()

# %%
# therefore there are no outliers in the dataset as we can see in the above plots

# %%
# plt.figure(figsize=(15,8))
# for i,cols in enumerate(categorical_columns):
#     plt.subplot(2,4,i+1)
#     plt.bar(df[cols].unique(),df[cols].value_counts(),color = ["red","green","blue","black"])
#     plt.title(cols)
#     plt.ylabel("counts")
# plt.tight_layout()
# plt.show()

# %%
# df[df['Drunk'] == 1]

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#         Age        BMI  Nmisc  Biking  Walking  Driving  Sitting  Location  \
# 0        22  16.688239      0       0        0        1        1         2
# 1        22  16.688239      0       0        0        1        1         1
# 2        22  16.688239      2       0        0        1        1         3
# 3        22  16.688239      0       0        1        0        1         2
# 4        22  16.688239      1       0        1        0        1         3
# ...     ...        ...    ...     ...      ...      ...      ...       ...
# 999995   34  26.530021      1       1        0        0        0         1
# 999996   34  26.530021      0       1        0        0        0         1
# 999997   34  26.530021      1       1        0        0        1         1
# 999998   34  26.530021      2       0        1        0        0         0
# 999999   34  26.530021      2       1        0        0        0         0
#
#         temp  bpm  stress  bp  Alcohol Consumption  Drunk  \
# ...

# %%
plt.figure(figsize = (10,8))

for i,col in enumerate(non_categorical_features):
    plt.subplot(2,3,i+1)
    sns.histplot(x = df[col])
    plt.title(col)
    plt.xlabel("Values")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 8))

for i, col in enumerate(categorical_columns):
    plt.subplot(2, 4, i + 1)
    counts = df[col].value_counts()
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
skew_values = []
for col in df.columns:
    skew_values.append({'Column': col, 'Skewness': df[col].skew()})
skew_df = pd.DataFrame(skew_values)
skew_df
# Out:
#                          Column   Skewness
# 0                           Age   0.000275
# 1                           BMI   0.000613
# 2                         Nmisc  -0.001570
# 3                        Biking   0.002744
# 4                       Walking   0.006881
# 5                       Driving  20.312570
# 6                       Sitting  -0.001664
# 7                      Location  -0.001552
# 8                          temp   0.034401
# 9                           bpm   0.443937
# 10                       stress   0.532642
# 11                           bp  -0.322839
# 12          Alcohol Consumption  -0.002203
# 13                        Drunk  -3.822898
# 14  Miscarriage/ No Miscarriage   0.002268

# %%
df['Driving'].value_counts().plot(kind='bar')
plt.title('Distribution of "driving" Feature')
plt.show()

# %%
correlation = df['Driving'].corr(df['Miscarriage/ No Miscarriage'])
print(f"Correlation between 'driving' and 'Miscarriage': {correlation}")
# Out:
# Correlation between 'driving' and 'Miscarriage': 0.0025868206504469156

# %%
variance = df['Driving'].var()
print(f"Variance of 'driving' feature: {variance}")
# Out:
# Variance of 'driving' feature: 0.0024003907648573407

# %%
# lets drop this column since the variance and the correlation is very low with the target column

# %%
df.drop("Driving",axis = 1,inplace = True)

# %%
df
# Out:
#         Age        BMI  Nmisc  Biking  Walking  Sitting  Location  temp  bpm  \
# 0        22  16.688239      0       0        0        1         2    38  103
# 1        22  16.688239      0       0        0        1         1    36  103
# 2        22  16.688239      2       0        0        1         3    38  103
# 3        22  16.688239      0       0        1        1         2    39  102
# 4        22  16.688239      1       0        1        1         3    35  102
# ...     ...        ...    ...     ...      ...      ...       ...   ...  ...
# 999995   34  26.530021      1       1        0        0         1    35  103
# 999996   34  26.530021      0       1        0        0         1    39  103
# 999997   34  26.530021      1       1        0        1         1    36  103
# 999998   34  26.530021      2       0        1        0         0    39  103
# 999999   34  26.530021      2       1        0        0         0    41   90
#
# ...

# %%
df['Drunk'].value_counts().plot(kind='bar')
plt.title('Distribution of "drunk" Feature')
plt.show()

# %%
correlation = df['Drunk'].corr(df['Miscarriage/ No Miscarriage'])
print(f"Correlation between 'Drunk' and 'Miscarriage': {correlation}")
# Out:
# Correlation between 'Drunk' and 'Miscarriage': 0.0005182426842454459

# %%
variance = df['Drunk'].var()
print(f"Variance of 'drunk' feature: {variance}")
# Out:
# Variance of 'drunk' feature: 0.17768951464527488

# %%
# since the drunk column is also having the high imbalance, low variance and almost negligible correlation lets also drop this

# %%
df.drop("Drunk",axis= 1,inplace = True)

# %%
df
# Out:
#         Age        BMI  Nmisc  Biking  Walking  Sitting  Location  temp  bpm  \
# 0        22  16.688239      0       0        0        1         2    38  103
# 1        22  16.688239      0       0        0        1         1    36  103
# 2        22  16.688239      2       0        0        1         3    38  103
# 3        22  16.688239      0       0        1        1         2    39  102
# 4        22  16.688239      1       0        1        1         3    35  102
# ...     ...        ...    ...     ...      ...      ...       ...   ...  ...
# 999995   34  26.530021      1       1        0        0         1    35  103
# 999996   34  26.530021      0       1        0        0         1    39  103
# 999997   34  26.530021      1       1        0        1         1    36  103
# 999998   34  26.530021      2       0        1        0         0    39  103
# 999999   34  26.530021      2       1        0        0         0    41   90
#
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#         Age        BMI  Nmisc  Biking  Walking  Sitting  Location  temp  bpm  \
# 0        22  16.688239      0       0        0        1         2    38  103
# 1        22  16.688239      0       0        0        1         1    36  103
# 2        22  16.688239      2       0        0        1         3    38  103
# 3        22  16.688239      0       0        1        1         2    39  102
# 4        22  16.688239      1       0        1        1         3    35  102
# ...     ...        ...    ...     ...      ...      ...       ...   ...  ...
# 999995   34  26.530021      1       1        0        0         1    35  103
# 999996   34  26.530021      0       1        0        0         1    39  103
# 999997   34  26.530021      1       1        0        1         1    36  103
# 999998   34  26.530021      2       0        1        0         0    39  103
# 999999   34  26.530021      2       1        0        0         0    41   90
#
# ...

# %%
stress_miscarriage = df[df['Miscarriage/ No Miscarriage'] == 1]['stress']
stress_no_miscarriage = df[df['Miscarriage/ No Miscarriage'] == 0]['stress']

plt.figure(figsize=(10, 6))
plt.hist([stress_miscarriage, stress_no_miscarriage], bins=20, stacked=True, label=['Miscarriage', 'No Miscarriage'], color=['red', 'green'])

plt.title('Distribution of Stress Levels for Each Target Class')
plt.xlabel('Stress Level')
plt.ylabel('Frequency')
plt.legend()

plt.show()

# %%
# from this is is clearly evident that the women with high stress may not have high concern of miscarraige, but was believed to be

# %%
bp_miscarriage = df[df['Miscarriage/ No Miscarriage'] == 1]['bp']
bp_no_miscarriage = df[df['Miscarriage/ No Miscarriage'] == 0]['bp']

plt.figure(figsize=(10, 6))
plt.hist([bp_miscarriage, bp_no_miscarriage], bins=20, stacked=True, label=['Miscarriage', 'No Miscarriage'], color=['red', 'green'])

plt.title('Distribution of bp Levels for Each Target Class')
plt.xlabel('bp')
plt.ylabel('Frequency')
plt.legend()

plt.show()

# %%
cross_tab = pd.crosstab(df["Age"],df["Miscarriage/ No Miscarriage"],normalize="columns")
cross_tab.plot(kind = "bar", stacked = True, color = ["red","black"])
plt.legend(['No Miscarriage', 'Miscarriage'], title='Target')
plt.title('Distribution of Age for Each Target Class')
plt.xlabel('Age Range')
plt.ylabel('Proportion')
plt.show()

# %% [markdown]
# ### Rough

# %%
df.corr()["Miscarriage/ No Miscarriage"]
# Out:
# Age                            0.247122
# BMI                            0.002024
# Nmisc                         -0.000251
# Activity                            NaN
# Biking                        -0.000862
# Walking                        0.000608
# Sitting                       -0.000023
# Location                       0.000180
# temp                          -0.001072
# bpm                           -0.000325
# stress                         0.000864
# bp                            -0.001034
# Alcohol Consumption           -0.000675
# Miscarriage/ No Miscarriage    1.000000
# Name: Miscarriage/ No Miscarriage, dtype: float64

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # end

# %%
# it is clear that the people of age group 24,25 28,33 had miscarried
# people of age group 22,23,26,27 had no miscarraige

# %%
X = df.drop("Miscarriage/ No Miscarriage",axis = 1)
y = df["Miscarriage/ No Miscarriage"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,stratify = y,random_state=42)

# %%
df.columns
# Out:
# Index(['Age', 'BMI', 'Nmisc', 'Activity', 'Biking', 'Walking', 'Sitting',
#        'Location', 'temp', 'bpm', 'stress', 'bp', 'Alcohol Consumption',
#        'Miscarriage/ No Miscarriage'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

scaler  = StandardScaler()
columns_to_normalise = ["Age","BMI","temp","bpm","Alcohol Consumption"]
X_train_scaled = X_train
X_test_scaled = X_test
X_train_scaled[columns_to_normalise] = scaler.fit_transform(X_train[columns_to_normalise])
X_test_scaled[columns_to_normalise] = scaler.transform(X_test[columns_to_normalise])

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, log_loss, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import label_binarize

knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train_scaled, y_train)

y_pred = knn.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Classification Report:")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred, average='weighted')  # 'weighted' for multi-class or imbalanced classes
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")


if len(set(y_test)) == 2:  # For binary classification
    auc = roc_auc_score(y_test, knn.predict_proba(X_test_scaled)[:, 1])
    print(f"ROC AUC: {auc:.2f}")

    fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test_scaled)[:, 1])
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'ROC curve (area = {auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  
    plt.title("Receiver Operating Characteristic (ROC) Curve")
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.legend(loc="lower right")
    plt.show()
else:
    print("ROC AUC is not calculated for multi-class classification directly.")

# Plotting the Confusion Matrix
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=set(y_test), yticklabels=set(y_test))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 63.75%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.61      0.63    150157
#            1       0.63      0.67      0.65    149816
#
#     accuracy                           0.64    299973
#    macro avg       0.64      0.64      0.64    299973
# weighted avg       0.64      0.64      0.64    299973
#
# Confusion Matrix:
# [[ 91155  59002]
#  [ 49726 100090]]
# Precision: 0.64
# Recall: 0.64
# F1-Score: 0.64
# ROC AUC: 0.68

# %%
import numpy as np
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import label_binarize

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[columns_to_normalise])

knn = KNeighborsClassifier(n_neighbors=5)

cv_scores = cross_val_score(knn, X_scaled, y, cv=5, scoring='accuracy')

print(f"Cross-Validation Accuracy Scores: {cv_scores}")
print(f"Mean Cross-Validation Accuracy: {np.mean(cv_scores) * 100:.2f}%")
print(f"Standard Deviation of Accuracy: {np.std(cv_scores) * 100:.2f}%")

y_pred_cv = cross_val_predict(knn, X_scaled, y, cv=5)

accuracy = accuracy_score(y, y_pred_cv)
print(f"Accuracy (cross-validation): {accuracy * 100:.2f}%")

print("Classification Report (cross-validation):")
print(classification_report(y, y_pred_cv))

conf_matrix = confusion_matrix(y, y_pred_cv)
print("Confusion Matrix (cross-validation):")
print(conf_matrix)

precision = precision_score(y, y_pred_cv, average='weighted')  
recall = recall_score(y, y_pred_cv, average='weighted')
f1 = f1_score(y, y_pred_cv, average='weighted')
print(f"Precision (cross-validation): {precision:.2f}")
print(f"Recall (cross-validation): {recall:.2f}")
print(f"F1-Score (cross-validation): {f1:.2f}")

if len(set(y)) == 2:  
    auc = roc_auc_score(y, knn.fit(X_scaled, y).predict_proba(X_scaled)[:, 1])
    print(f"ROC AUC (cross-validation): {auc:.2f}")

    fpr, tpr, thresholds = roc_curve(y, knn.fit(X_scaled, y).predict_proba(X_scaled)[:, 1])
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'ROC curve (area = {auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--') 
    plt.title("Receiver Operating Characteristic (ROC) Curve (cross-validation)")
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.legend(loc="lower right")
    plt.show()
else:
    print("ROC AUC is not calculated for multi-class classification directly.")
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=set(y), yticklabels=set(y))
plt.title("Confusion Matrix (cross-validation)")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Cross-Validation Accuracy Scores: [0.6833565  0.56178556 0.26627396 0.17885699 0.50042254]
# Mean Cross-Validation Accuracy: 43.81%
# Standard Deviation of Accuracy: 18.77%
# Accuracy (cross-validation): 43.81%
# Classification Report (cross-validation):
#               precision    recall  f1-score   support
#
#            0       0.44      0.46      0.45    500521
#            1       0.43      0.42      0.42    499387
#
#     accuracy                           0.44    999908
#    macro avg       0.44      0.44      0.44    999908
# weighted avg       0.44      0.44      0.44    999908
#
# Confusion Matrix (cross-validation):
# [[230695 269826]
#  [291983 207404]]
# Precision (cross-validation): 0.44
# Recall (cross-validation): 0.44
# F1-Score (cross-validation): 0.44
# ROC AUC (cross-validation): 0.96
# Log Loss (cross-validation): 0.22

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=1200)

log_reg.fit(X_train, y_train)

y_pred = log_reg.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Classification Report:")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred, average='weighted')  #for imbalance classes
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")


if len(set(y_test)) == 2:  
    auc = roc_auc_score(y_test, log_reg.predict_proba(X_test)[:, 1])
    print(f"ROC AUC: {auc:.2f}")

    fpr, tpr, thresholds = roc_curve(y_test, log_reg.predict_proba(X_test)[:, 1])
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'ROC curve (area = {auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
    plt.title("Receiver Operating Characteristic (ROC) Curve")
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.legend(loc="lower right")
    plt.show()
else:
    print("ROC AUC is not calculated for multi-class classification directly.")
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=set(y_test), yticklabels=set(y_test))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 61.17%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.62      0.61    150157
#            1       0.61      0.61      0.61    149816
#
#     accuracy                           0.61    299973
#    macro avg       0.61      0.61      0.61    299973
# weighted avg       0.61      0.61      0.61    299973
#
# Confusion Matrix:
# [[92385 57772]
#  [58705 91111]]
# Precision: 0.61
# Recall: 0.61
# F1-Score: 0.61
# ROC AUC: 0.64

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier(random_state=42)  

decision_tree.fit(X_train, y_train)

y_pred = decision_tree.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Classification Report:")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred, average='weighted')  # 'weighted' for multi-class or imbalanced classes
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")

if len(set(y_test)) == 2:  
    auc = roc_auc_score(y_test, decision_tree.predict_proba(X_test)[:, 1])
    print(f"ROC AUC: {auc:.2f}")
    fpr, tpr, thresholds = roc_curve(y_test, decision_tree.predict_proba(X_test)[:, 1])
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'ROC curve (area = {auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
    plt.title("Receiver Operating Characteristic (ROC) Curve")
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.legend(loc="lower right")
    plt.show()
else:
    print("ROC AUC is not calculated for multi-class classification directly.")

plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=set(y_test), yticklabels=set(y_test))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 80.82%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81    150157
#            1       0.81      0.81      0.81    149816
#
#     accuracy                           0.81    299973
#    macro avg       0.81      0.81      0.81    299973
# weighted avg       0.81      0.81      0.81    299973
#
# Confusion Matrix:
# [[121394  28763]
#  [ 28773 121043]]
# Precision: 0.81
# Recall: 0.81
# F1-Score: 0.81
# ROC AUC: 0.81

# %%
from sklearn.naive_bayes import GaussianNB
naive_bayes = GaussianNB()

naive_bayes.fit(X_train_scaled, y_train)

y_pred = naive_bayes.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Classification Report:")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred, average='weighted')  
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")


if len(set(y_test)) == 2:  
    auc = roc_auc_score(y_test, naive_bayes.predict_proba(X_test_scaled)[:, 1])
    print(f"ROC AUC: {auc:.2f}")

    fpr, tpr, thresholds = roc_curve(y_test, naive_bayes.predict_proba(X_test_scaled)[:, 1])
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'ROC curve (area = {auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  
    plt.title("Receiver Operating Characteristic (ROC) Curve")
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.legend(loc="lower right")
    plt.show()
else:
    print("ROC AUC is not calculated for multi-class classification directly.")
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=set(y_test), yticklabels=set(y_test))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 65.39%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.62      0.64    150157
#            1       0.64      0.69      0.67    149816
#
#     accuracy                           0.65    299973
#    macro avg       0.65      0.65      0.65    299973
# weighted avg       0.65      0.65      0.65    299973
#
# Confusion Matrix:
# [[ 92580  57577]
#  [ 46233 103583]]
# Precision: 0.65
# Recall: 0.65
# F1-Score: 0.65
# ROC AUC: 0.64

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)  # Adjust n_estimators as needed

random_forest.fit(X_train, y_train)

y_pred = random_forest.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Classification Report:")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred, average='weighted')  
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
if len(set(y_test)) == 2:  # For binary classification
    auc = roc_auc_score(y_test, random_forest.predict_proba(X_test)[:, 1])
    print(f"ROC AUC: {auc:.2f}")

    fpr, tpr, thresholds = roc_curve(y_test, random_forest.predict_proba(X_test)[:, 1])
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'ROC curve (area = {auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
    plt.title("Receiver Operating Characteristic (ROC) Curve")
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.legend(loc="lower right")
    plt.show()
else:
    print("ROC AUC is not calculated for multi-class classification directly.")



plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=set(y_test), yticklabels=set(y_test))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 80.80%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80    150157
#            1       0.79      0.84      0.81    149816
#
#     accuracy                           0.81    299973
#    macro avg       0.81      0.81      0.81    299973
# weighted avg       0.81      0.81      0.81    299973
#
# Confusion Matrix:
# [[116144  34013]
#  [ 23581 126235]]
# Precision: 0.81
# Recall: 0.81
# F1-Score: 0.81
# ROC AUC: 0.93

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, log_loss, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns

xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Classification Report:")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred, average='weighted')  # 'weighted' for multi-class or imbalanced classes
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
if len(set(y_test)) == 2:  
    auc = roc_auc_score(y_test, xgb_model.predict_proba(X_test)[:, 1])
    print(f"ROC AUC: {auc:.2f}")

    fpr, tpr, thresholds = roc_curve(y_test, xgb_model.predict_proba(X_test)[:, 1])
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'ROC curve (area = {auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
    plt.title("Receiver Operating Characteristic (ROC) Curve")
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.legend(loc="lower right")
    plt.show()
else:
    print("ROC AUC is not calculated for multi-class classification directly.")
plt.figure(figsize=(6, 6))

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=set(y_test), yticklabels=set(y_test))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 80.83%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81    150157
#            1       0.81      0.81      0.81    149816
#
#     accuracy                           0.81    299973
#    macro avg       0.81      0.81      0.81    299973
# weighted avg       0.81      0.81      0.81    299973
#
# Confusion Matrix:
# [[121433  28724]
#  [ 28788 121028]]
# Precision: 0.81
# Recall: 0.81
# F1-Score: 0.81
# ROC AUC: 0.93

# %%
from sklearn.ensemble import AdaBoostClassifier

adaboost_model = AdaBoostClassifier(n_estimators=50, random_state=42)

]adaboost_model.fit(X_train, y_train)

y_pred = adaboost_model.predict(X_test)

]accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

]print("Classification Report:")
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred, average='weighted')  
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")

if len(set(y_test)) == 2:  
    auc = roc_auc_score(y_test, adaboost_model.predict_proba(X_test)[:, 1])
    print(f"ROC AUC: {auc:.2f}")
    fpr, tpr, thresholds = roc_curve(y_test, adaboost_model.predict_proba(X_test)[:, 1])
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'ROC curve (area = {auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
    plt.title("Receiver Operating Characteristic (ROC) Curve")
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.legend(loc="lower right")
    plt.show()
else:
    print("ROC AUC is not calculated for multi-class classification directly.")
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=set(y_test), yticklabels=set(y_test))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 80.81%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.62      0.76    150157
#            1       0.72      1.00      0.84    149816
#
#     accuracy                           0.81    299973
#    macro avg       0.86      0.81      0.80    299973
# weighted avg       0.86      0.81      0.80    299973
#
# Confusion Matrix:
# [[ 92580  57577]
#  [     0 149816]]
# Precision: 0.86
# Recall: 0.81
# F1-Score: 0.80
# ROC AUC: 0.93

# %%
df
# Out:
#         Age        BMI  Nmisc  Biking  Walking  Sitting  Location  temp  bpm  \
# 0        22  16.688239      0       0        0        1         2    38  103
# 1        22  16.688239      0       0        0        1         1    36  103
# 2        22  16.688239      2       0        0        1         3    38  103
# 3        22  16.688239      0       0        1        1         2    39  102
# 4        22  16.688239      1       0        1        1         3    35  102
# ...     ...        ...    ...     ...      ...      ...       ...   ...  ...
# 999995   34  26.530021      1       1        0        0         1    35  103
# 999996   34  26.530021      0       1        0        0         1    39  103
# 999997   34  26.530021      1       1        0        1         1    36  103
# 999998   34  26.530021      2       0        1        0         0    39  103
# 999999   34  26.530021      2       1        0        0         0    41   90
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## crossValidation model evaluation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

log_reg = LogisticRegression(max_iter=1200)

# cross-validation
cv_scores = cross_val_score(log_reg, X_train, y_train, cv=5, scoring='accuracy')

print("Cross-validation scores:", cv_scores)
print(f"Average cross-validation accuracy: {np.mean(cv_scores) * 100:.2f}%")

log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Test set accuracy: {accuracy * 100:.2f}%")
# Out:
# Cross-validation scores: [0.61419275 0.61469994 0.60772072 0.60849222 0.61152821]
# Average cross-validation accuracy: 61.13%
# Test set accuracy: 61.17%

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

decision_tree = DecisionTreeClassifier(random_state=42)

# cross-validation
cv_scores = cross_val_score(decision_tree, X_train, y_train, cv=5, scoring='accuracy')

print("Cross-validation scores:", cv_scores)
print(f"Average cross-validation accuracy: {np.mean(cv_scores) * 100:.2f}%")

decision_tree.fit(X_train, y_train)

y_pred = decision_tree.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Test set accuracy: {accuracy * 100:.2f}%")
# Out:
# Cross-validation scores: [0.80648917 0.80830363 0.8084465  0.80791788 0.80661776]
# Average cross-validation accuracy: 80.76%
# Test set accuracy: 80.82%

# %%
from sklearn.naive_bayes import GaussianNB

naive_bayes = GaussianNB()

cv_scores = cross_val_score(naive_bayes, X_train, y_train, cv=5, scoring='accuracy')

print("Cross-validation scores:", cv_scores)
print(f"Average cross-validation accuracy: {np.mean(cv_scores) * 100:.2f}%")

naive_bayes.fit(X_train, y_train)

y_pred = naive_bayes.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Test set accuracy: {accuracy * 100:.2f}%")
# Out:
# Cross-validation scores: [0.65439648 0.65596091 0.65357497 0.65435362 0.65236058]
# Average cross-validation accuracy: 65.41%
# Test set accuracy: 65.39%

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier


random_forest = RandomForestClassifier(n_estimators=100, random_state=42)  # Adjust n_estimators as needed

cv_scores = cross_val_score(random_forest, X_train, y_train, cv=5, scoring='accuracy')

print("Cross-validation scores:", cv_scores)
print(f"Average cross-validation accuracy: {np.mean(cv_scores) * 100:.2f}%")

random_forest.fit(X_train, y_train)

y_pred = random_forest.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Test set accuracy: {accuracy * 100:.2f}%")
# Out:
# Cross-validation scores: [0.80616057 0.80674634 0.80808218 0.80829648 0.80661776]
# Average cross-validation accuracy: 80.72%
# Test set accuracy: 80.80%

# %%
# !pip install --upgrade scikit-learn xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.1 MB 1.2 MB/s eta 0:00:10
#     --------------------------------------- 0.2/11.1 MB 1.1 MB/s eta 0:00:10
#     --------------------------------------- 0.2/11.1 MB 1.2 MB/s eta 0:00:09
#     --------------------------------------- 0.2/11.1 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.3/11.1 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/11.1 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/11.1 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/11.1 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/11.1 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/11.1 MB 1.1 MB/s eta 0:00:10
# ...

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

cv_scores = cross_val_score(xgb_model, X_train, y_train, cv=5, scoring='accuracy')

print("Cross-validation scores:", cv_scores)
print(f"Average cross-validation accuracy: {np.mean(cv_scores) * 100:.2f}%")

xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Test set accuracy: {accuracy * 100:.2f}%")
# Out:
# Cross-validation scores: [0.80664633 0.80864652 0.8064106  0.80760356 0.80683921]
# Average cross-validation accuracy: 80.72%
# Test set accuracy: 80.83%

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
print(tf.__version__)  # This will print the installed TensorFlow version
# Out:
# 2.18.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam


# Building the Neural Network model
model = Sequential()

# Input layer and first hidden layer
model.add(Dense(16, activation='relu', input_dim=X_train_scaled.shape[1]))

# Second hidden layer
model.add(Dense(8, activation='relu'))

# Output layer (binary classification)
model.add(Dense(1, activation='sigmoid'))

# Compiling the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Training the model on the training data
history = model.fit(X_train_scaled, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=1)

# Making predictions on the test set
y_pred_probs = model.predict(X_test_scaled)
y_pred = (y_pred_probs > 0.5).astype(int)  # Convert probabilities to binary predictions

# Calculating accuracy on the test set
accuracy = accuracy_score(y_test, y_pred)
print(f"Test set accuracy: {accuracy * 100:.2f}%")

# Calculating other metrics
roc_auc = roc_auc_score(y_test, y_pred_probs)
conf_matrix = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("\nConfusion Matrix:")
print(conf_matrix)

print("\nClassification Report:")
print(report)

print(f"ROC-AUC Score: {roc_auc:.2f}")

# Plot the ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# Epoch 1/20
# 17499/17499 ━━━━━━━━━━━━━━━━━━━━ 49s 3ms/step - accuracy: 0.6774 - loss: 0.5309 - val_accuracy: 0.8075 - val_loss: 0.3100
# Epoch 2/20
# 17499/17499 ━━━━━━━━━━━━━━━━━━━━ 36s 2ms/step - accuracy: 0.8076 - loss: 0.3048 - val_accuracy: 0.8064 - val_loss: 0.2833
# Epoch 3/20
# 17499/17499 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - accuracy: 0.8067 - loss: 0.2779 - val_accuracy: 0.8065 - val_loss: 0.2689
# Epoch 4/20
# 17499/17499 ━━━━━━━━━━━━━━━━━━━━ 37s 2ms/step - accuracy: 0.8070 - loss: 0.2676 - val_accuracy: 0.8067 - val_loss: 0.2683
# Epoch 5/20
# 17499/17499 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.8083 - loss: 0.2667 - val_accuracy: 0.8068 - val_loss: 0.2682
# Epoch 6/20
# 17499/17499 ━━━━━━━━━━━━━━━━━━━━ 45s 2ms/step - accuracy: 0.8073 - loss: 0.2672 - val_accuracy: 0.8065 - val_loss: 0.2681
# Epoch 7/20
# 17499/17499 ━━━━━━━━━━━━━━━━━━━━ 37s 2ms/step - accuracy: 0.8077 - loss: 0.2672 - val_accuracy: 0.8067 - val_loss: 0.2681
# Epoch 8/20
# ...

# %%
# Convert y_train to NumPy array if it's a pandas Series
y_train = y_train.to_numpy() if isinstance(y_train, pd.Series) else y_train

# Set up KFold cross-validation (5 splits)
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# List to store accuracy for each fold
cv_accuracies = []

# Loop over the folds
for train_index, val_index in kf.split(X_train_scaled):
    # Split the data for this fold
    X_train_cv, X_val_cv = X_train_scaled[train_index], X_train_scaled[val_index]
    y_train_cv, y_val_cv = y_train[train_index], y_train[val_index]

    # Building the model
    model = Sequential([
        Dense(16, activation='relu', input_dim=X_train_cv.shape[1]),
        Dense(8, activation='relu'),
        Dense(1, activation='sigmoid')
    ])

    # Compiling the model
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

    # Training the model
    model.fit(X_train_cv, y_train_cv, epochs=7, batch_size=32, validation_data=(X_val_cv, y_val_cv), verbose=0)

    # calculatin accuracy
    y_pred_probs = model.predict(X_val_cv)
    y_pred = (y_pred_probs > 0.5).astype(int)
    accuracy = accuracy_score(y_val_cv, y_pred)

    # Store the accuracy for this fold
    cv_accuracies.append(accuracy)

#printing the average accuracy
average_accuracy = np.mean(cv_accuracies) * 100
print(f"Average Cross-validation Accuracy: {average_accuracy:.2f}%")
# Out:
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 4s 878us/step
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 4s 927us/step
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 4s 865us/step
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 4s 939us/step
# Average Cross-validation Accuracy: 80.69%

# %%
random_forest
# Out:
# RandomForestClassifier(random_state=42)

# %%
feature_importances = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': random_forest.feature_importances_
}).sort_values(by='Importance', ascending=False)

# Plotting feature importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importances['Feature'], feature_importances['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.title('Feature Importance')
plt.gca().invert_yaxis()
plt.show()

# %%
pip install lime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
